# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from sklearn.metrics import accuracy_score , classification_report

# %%
df = sns.load_dataset('iris')

# %%
# independent & dependent features 

X = df.iloc[:, :-1] # take all the rows & all columns except last one 
Y = iris.target

# %%
# train test split 

X_train, X_test, Y_train , Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 38 )

# %%
# Post-Pruning technique as here we do not specify any parameters to the decision tree in advance 
treemodel = DecisionTreeClassifier()

# %%
treemodel.fit(X_train, Y_train) # train the model
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(15, 10))

tree.plot_tree(treemodel, filled = True)
# Out:
# [Text(0.4, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.666\nsamples = 105\nvalue = [33, 37, 35]'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 33\nvalue = [33, 0, 0]'),
#  Text(0.5, 0.75, 'x[2] <= 4.85\ngini = 0.5\nsamples = 72\nvalue = [0, 37, 35]'),
#  Text(0.2, 0.5833333333333334, 'x[3] <= 1.65\ngini = 0.102\nsamples = 37\nvalue = [0, 35, 2]'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.3, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.108\nsamples = 35\nvalue = [0, 2, 33]'),
#  Text(0.7, 0.4166666666666667, 'x[0] <= 6.5\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.25, 'x[2] <= 5.4\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
# prediction stage 

Y_pred = treemodel.predict(X_test)


score = accuracy_score(Y_pred, Y_test)


print(score*100, '% Accuracy')
# Out:
# 95.55555555555556 % Accuracy
